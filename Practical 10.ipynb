# %% [markdown]
# **Practical 10**<br>
# Download the Iris flower dataset or any other dataset into a DataFrame. (e.g.,
# https://archive.ics.uci.edu/ml/datasets/Iris ). Scan the dataset and give the inference as:

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/DSBDA prac/Datasets/Iris.csv')

# %%
data.drop(['Id'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Part 1: List down the features and their types (e.g., numeric, nominal) available in the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Part 2: Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
plt.figure(figsize=(12, 12))
data.hist()
plt.show()

# %% [markdown]
# Part 3: Create a box plot for each feature in the dataset.

# %%
sn.set_style('whitegrid')
plt.figure(figsize=(12, 12))
sn.boxplot(data=data)

# %% [markdown]
# Part 4: Compare distributions and identify outliers.

# %%
sn.catplot(x="Species",y="SepalLengthCm", data=data)

# %%
sn.catplot(x="Species",y="SepalWidthCm", data=data)

# %%
sn.catplot(x="Species",y="PetalLengthCm", data=data)

# %%
sn.catplot(x="Species",y="PetalWidthCm", data=data)
